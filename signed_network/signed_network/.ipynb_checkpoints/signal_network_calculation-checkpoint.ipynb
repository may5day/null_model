# %%
% matplotlib inline 
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import networkx as nx
import sign_null_model_undirected as sm
import sign_null_model_directed as smd

# %%
def loadfile():
    with open(filename) as f:
        edges = []
        for each_line in f:
            #print each_line
            n1,n2,w = each_line.strip('\t\r\n').split('\t')
            edges.append((n1,n2,int(w)))
        return edges

# %%
#filename = 'N46edge.txt'
filename = 'epinions.txt'
G = nx.Graph()
G.add_weighted_edges_from(loadfile())

# %%
#filename = 'N46edge.txt'
filename = 'epinions.txt'
Gd = nx.DiGraph()
Gd.add_weighted_edges_from(loadfile())

# %%
nswap=1000000
max_tries=5000000

# %%
G1 = sm.sign_network_positive_swap(G, nswap, max_tries)           #正边交换
G2 = sm.sign_network_negative_swap(G, nswap, max_tries)           #负边交换
G3 = sm.sign_network_negative_swap(G1, nswap, max_tries)          #正负边分别进行交换：先交换正边，再交换负边
G4 = sm.sign_network_sign_swap(G, nswap, max_tries)               #符号交换
G5 = sm.sign_network_full_swap(G, nswap, max_tries)               #正负边同时进行交换
# Out:
# swap times= 64284 try times= 100000
# swap times= 128486 try times= 200000
# swap times= 192762 try times= 300000
# swap times= 257255 try times= 400000
# swap times= 321592 try times= 500000
# swap times= 385890 try times= 600000
# swap times= 449727 try times= 700000
# swap times= 513873 try times= 800000
# swap times= 577906 try times= 900000
# swap times= 642441 try times= 1000000
# swap times= 706715 try times= 1100000
# swap times= 771169 try times= 1200000
# swap times= 835166 try times= 1300000
# swap times= 899355 try times= 1400000
# swap times= 963745 try times= 1500000
# swap times= 2516 try times= 100000
# swap times= 4995 try times= 200000
# swap times= 7486 try times= 300000
# swap times= 9904 try times= 400000
# swap times= 12332 try times= 500000
# swap times= 14782 try times= 600000
# swap times= 17296 try times= 700000
# swap times= 19779 try times= 800000
# swap times= 22228 try times= 900000
# swap times= 24666 try times= 1000000
# swap times= 27153 try times= 1100000
# swap times= 29546 try times= 1200000
# swap times= 31977 try times= 1300000
# swap times= 34517 try times= 1400000
# swap times= 36960 try times= 1500000
# swap times= 39411 try times= 1600000
# swap times= 41824 try times= 1700000
# swap times= 44315 try times= 1800000
# swap times= 46729 try times= 1900000
# swap times= 49249 try times= 2000000
# swap times= 51708 try times= 2100000
# swap times= 54178 try times= 2200000
# swap times= 56638 try times= 2300000
# swap times= 59078 try times= 2400000
# swap times= 61519 try times= 2500000
# swap times= 64007 try times= 2600000
# swap times= 66460 try times= 2700000
# swap times= 68968 try times= 2800000
# swap times= 71430 try times= 2900000
# swap times= 73998 try times= 3000000
# swap times= 76451 try times= 3100000
# swap times= 78896 try times= 3200000
# swap times= 81318 try times= 3300000
# swap times= 83830 try times= 3400000
# swap times= 86219 try times= 3500000
# swap times= 88617 try times= 3600000
# swap times= 91009 try times= 3700000
# swap times= 93536 try times= 3800000
# swap times= 95947 try times= 3900000
# swap times= 98406 try times= 4000000
# swap times= 100787 try times= 4100000
# swap times= 103095 try times= 4200000
# swap times= 105568 try times= 4300000
# swap times= 108014 try times= 4400000
# swap times= 110510 try times= 4500000
# swap times= 112909 try times= 4600000
# swap times= 115232 try times= 4700000
# swap times= 117609 try times= 4800000
# swap times= 120097 try times= 4900000
# swap times= 122564 try times= 5000000
# Maximum number of swap attempts (5000000) exceeded before desired swaps achieved (1000000).
# swap times= 2587 try times= 100000
# swap times= 5180 try times= 200000
# swap times= 7674 try times= 300000
# swap times= 10157 try times= 400000
# swap times= 12564 try times= 500000
# swap times= 15053 try times= 600000
# swap times= 17549 try times= 700000
# swap times= 20065 try times= 800000
# swap times= 22577 try times= 900000
# swap times= 25098 try times= 1000000
# swap times= 27579 try times= 1100000
# swap times= 30139 try times= 1200000
# swap times= 32661 try times= 1300000
# swap times= 35177 try times= 1400000
# swap times= 37599 try times= 1500000
# swap times= 40106 try times= 1600000
# swap times= 42547 try times= 1700000
# swap times= 45064 try times= 1800000
# swap times= 47500 try times= 1900000
# swap times= 49979 try times= 2000000
# swap times= 52414 try times= 2100000
# swap times= 54862 try times= 2200000
# swap times= 57314 try times= 2300000
# swap times= 59815 try times= 2400000
# swap times= 62273 try times= 2500000
# swap times= 64723 try times= 2600000
# swap times= 67112 try times= 2700000
# swap times= 69552 try times= 2800000
# swap times= 71973 try times= 2900000
# swap times= 74501 try times= 3000000
# swap times= 76960 try times= 3100000
# swap times= 79369 try times= 3200000
# swap times= 81893 try times= 3300000
# swap times= 84352 try times= 3400000
# swap times= 86868 try times= 3500000
# swap times= 89374 try times= 3600000
# swap times= 91834 try times= 3700000
# swap times= 94332 try times= 3800000
# swap times= 96821 try times= 3900000
# swap times= 99361 try times= 4000000
# swap times= 101850 try times= 4100000
# swap times= 104264 try times= 4200000
# swap times= 106701 try times= 4300000
# swap times= 109157 try times= 4400000
# swap times= 111618 try times= 4500000
# swap times= 114145 try times= 4600000
# swap times= 116660 try times= 4700000
# swap times= 119203 try times= 4800000
# swap times= 121623 try times= 4900000
# swap times= 124017 try times= 5000000
# Maximum number of swap attempts (5000000) exceeded before desired swaps achieved (1000000).
# swap times= 27906 try times= 100000
# swap times= 55506 try times= 200000
# swap times= 83290 try times= 300000
# swap times= 111284 try times= 400000
# swap times= 139114 try times= 500000
# swap times= 167176 try times= 600000
# swap times= 194643 try times= 700000
# swap times= 222748 try times= 800000
# swap times= 250691 try times= 900000
# swap times= 278405 try times= 1000000
# swap times= 306170 try times= 1100000
# swap times= 333918 try times= 1200000
# swap times= 361776 try times= 1300000
# swap times= 389787 try times= 1400000
# swap times= 417916 try times= 1500000
# swap times= 445867 try times= 1600000
# swap times= 473849 try times= 1700000
# swap times= 501942 try times= 1800000
# swap times= 529610 try times= 1900000
# swap times= 557512 try times= 2000000
# swap times= 585560 try times= 2100000
# swap times= 613659 try times= 2200000
# swap times= 641398 try times= 2300000
# swap times= 669622 try times= 2400000
# swap times= 697487 try times= 2500000
# swap times= 725557 try times= 2600000
# swap times= 753436 try times= 2700000
# swap times= 781063 try times= 2800000
# swap times= 809117 try times= 2900000
# swap times= 837080 try times= 3000000
# swap times= 864855 try times= 3100000
# swap times= 892795 try times= 3200000
# swap times= 920739 try times= 3300000
# swap times= 948500 try times= 3400000
# swap times= 976475 try times= 3500000
# swap times= 92504 try times= 100000
# swap times= 184998 try times= 200000
# swap times= 277211 try times= 300000
# swap times= 369482 try times= 400000
# swap times= 461765 try times= 500000
# swap times= 554196 try times= 600000
# swap times= 646664 try times= 700000
# swap times= 739066 try times= 800000
# swap times= 831389 try times= 900000
# swap times= 923773 try times= 1000000

# %%
filename1 = 'epinions_positive_swap.txt'
with open(filename1,'w')as f1:
    nx.write_weighted_edgelist(G1, f1)

# %%
filename2 = 'epinions_negative_swap.txt'
with open(filename2,'w')as f2:
    nx.write_weighted_edgelist(G2, f2)

# %%
filename3 = 'epinions_positive_negative_swap.txt'
with open(filename3,'w')as f3:
    nx.write_weighted_edgelist(G3, f3)

# %%
filename4 = 'epinions_sign_swap.txt'
with open(filename4,'w')as f4:
    nx.write_weighted_edgelist(G4, f4)

# %%
filename5 = 'epinions_full_swap.txt'
with open(filename5,'w')as f5:
    nx.write_weighted_edgelist(G5, f5)

# %%
Gd1 = smd.sign_network_positive_swap(Gd, nswap, max_tries)           #正边交换
Gd2 = smd.sign_network_negative_swap(Gd, nswap, max_tries)           #负边交换
Gd3 = smd.sign_network_negative_swap(Gd1, nswap, max_tries)          #正负边分别进行交换：先交换正边，再交换负边
Gd4 = smd.sign_network_sign_swap(Gd, nswap, max_tries)               #符号交换
Gd5 = smd.sign_network_full_swap(Gd, nswap, max_tries)               #正负边同时进行交换
# Out:
# swap times= 67801 try times= 100000
# swap times= 136662 try times= 200000
# swap times= 206520 try times= 300000
# swap times= 276765 try times= 400000
# swap times= 347525 try times= 500000
# swap times= 418660 try times= 600000
# swap times= 489841 try times= 700000
# swap times= 561597 try times= 800000
# swap times= 633488 try times= 900000
# swap times= 705460 try times= 1000000
# swap times= 777530 try times= 1100000
# swap times= 849781 try times= 1200000
# swap times= 922014 try times= 1300000
# swap times= 994471 try times= 1400000
# swap times= 2291 try times= 100000
# swap times= 4746 try times= 200000
# swap times= 7124 try times= 300000
# swap times= 9611 try times= 400000
# swap times= 12030 try times= 500000
# swap times= 14555 try times= 600000
# swap times= 17170 try times= 700000
# swap times= 19781 try times= 800000
# swap times= 22376 try times= 900000
# swap times= 24983 try times= 1000000
# swap times= 27480 try times= 1100000
# swap times= 30046 try times= 1200000
# swap times= 32684 try times= 1300000
# swap times= 35301 try times= 1400000
# swap times= 37900 try times= 1500000
# swap times= 40462 try times= 1600000
# swap times= 43111 try times= 1700000
# swap times= 45735 try times= 1800000
# swap times= 48340 try times= 1900000
# swap times= 50990 try times= 2000000
# swap times= 53485 try times= 2100000
# swap times= 56067 try times= 2200000
# swap times= 58641 try times= 2300000
# swap times= 61279 try times= 2400000
# swap times= 63908 try times= 2500000
# swap times= 66491 try times= 2600000
# swap times= 68970 try times= 2700000
# swap times= 71526 try times= 2800000
# swap times= 74085 try times= 2900000
# swap times= 76615 try times= 3000000
# swap times= 79174 try times= 3100000
# swap times= 81756 try times= 3200000
# swap times= 84288 try times= 3300000
# swap times= 86857 try times= 3400000
# swap times= 89443 try times= 3500000
# swap times= 91942 try times= 3600000
# swap times= 94495 try times= 3700000
# swap times= 97040 try times= 3800000
# swap times= 99662 try times= 3900000
# swap times= 102271 try times= 4000000
# swap times= 104788 try times= 4100000
# swap times= 107300 try times= 4200000
# swap times= 109854 try times= 4300000
# swap times= 112328 try times= 4400000
# swap times= 114849 try times= 4500000
# swap times= 117348 try times= 4600000
# swap times= 119863 try times= 4700000
# swap times= 122327 try times= 4800000
# swap times= 124788 try times= 4900000
# swap times=

# %%
filename1 = 'epinions_positive_swap_d.txt'
with open(filename1,'w')as f1:
    nx.write_weighted_edgelist(Gd1, f1)

# %%
filename2 = 'epinions_negative_swap_d.txt'
with open(filename2,'w')as f2:
    nx.write_weighted_edgelist(Gd2, f2)

# %%
filename3 = 'epinions_positive_negative_swap_d.txt'
with open(filename3,'w')as f3:
    nx.write_weighted_edgelist(Gd3, f3)

# %%
filename4 = 'epinions_sign_swap_d.txt'
with open(filename4,'w')as f4:
    nx.write_weighted_edgelist(Gd4, f4)

# %%
filename5 = 'epinions_full_swap_d.txt'
with open(filename5,'w')as f5:
    nx.write_weighted_edgelist(Gd5, f5)

# %%
filename0 = 'epinions_origin_d.txt'
with open(filename0,'w')as f0:
    nx.write_weighted_edgelist(Gd, f0)

# %%
def divide_network(G):
    edge_list=[]
    for i,j,weight_data in G.edges(data=True):
        if 'weight' in weight_data:
            edge_list.append([i,j,weight_data['weight']])
            
    positive_edges=[]
    negitive_edges=[]
    for item in edge_list:
        if item[2]==1:       
            positive_edges.append(item)
        if item[2]==2:       
            negitive_edges.append(item)
        
    Gp= nx.Graph()
    Gp.add_weighted_edges_from(positive_edges)
        
    Gn= nx.Graph()
    Gn.add_weighted_edges_from(negitive_edges)
    return Gp,Gn

# %%
Gp,Gn=divide_network(G)
rp0=nx.degree_assortativity_coefficient(Gp)
rn0=nx.degree_assortativity_coefficient(Gn)
print("The assortativity coefficient of positive edges in the original network is ","%3.3f" %rp0)
print("The assortativity coefficient of negative edges in the original network is ","%3.3f" %rn0)
# Out:
# ('The assortativity coefficient of positive edges in the original network is ', '-0.052')
# ('The assortativity coefficient of negative edges in the original network is ', '-0.144')

# %%
knn_p0=nx.k_nearest_neighbors(Gp)
knn_n0=nx.k_nearest_neighbors(Gn)

# %%
Gp,Gn=divide_network(G1)
rp1=nx.degree_assortativity_coefficient(Gp)
rn1=nx.degree_assortativity_coefficient(Gn)
print("the rc of positive edges in G1 is ","%3.3f" %rp1),
print("the rc of positive edges in G1 is ","%3.3f" %rn1)
# Out:
# ('the rc of positive edges in G1 is ', '-0.057') ('the rc of positive edges in G1 is ', '-0.144')

# %%
knn_p1=nx.k_nearest_neighbors(Gp)
knn_n1=nx.k_nearest_neighbors(Gn)

# %%
Gp,Gn=divide_network(G2)
rp2=nx.degree_assortativity_coefficient(Gp)
rn2=nx.degree_assortativity_coefficient(Gn)
print("The rc of positive edges in G2 is ","%3.3f" %rp2),
print("The rc of positive edges in G2 is ","%3.3f" %rn2)
# Out:
# ('The rc of positive edges in G2 is ', '-0.052') ('The rc of positive edges in G2 is ', '-0.109')

# %%
knn_p2=nx.k_nearest_neighbors(Gp)
knn_n2=nx.k_nearest_neighbors(Gn)

# %%
Gp,Gn=divide_network(G3)
rp3=nx.degree_assortativity_coefficient(Gp)
rn3=nx.degree_assortativity_coefficient(Gn)
print("the rc of positive edges in G3 is ","%3.3f" %rp3)
print("The rc of positive edges in G3 is ","%3.3f" %rn3)
# Out:
# ('the rc of positive edges in G3 is ', '-0.057')
# ('The rc of positive edges in G3 is ', '-0.103')

# %%
knn_p3=nx.k_nearest_neighbors(Gp)
knn_n3=nx.k_nearest_neighbors(Gn)

# %%
Gp,Gn=divide_network(G4)
rp4=nx.degree_assortativity_coefficient(Gp)
rn4=nx.degree_assortativity_coefficient(Gn)
print("The rc of positive edges in G4 is ","%3.3f" %rp4)
print("The rc of positive edges in G4 is ","%3.3f" %rn4)
# Out:
# ('The rc of positive edges in G4 is ', '-0.070')
# ('The rc of positive edges in G4 is ', '-0.068')

# %%
knn_p4=nx.k_nearest_neighbors(Gp)
knn_n4=nx.k_nearest_neighbors(Gn)

# %%
Gp,Gn=divide_network(G5)
rp5=nx.degree_assortativity_coefficient(Gp)
rn5=nx.degree_assortativity_coefficient(Gn)
print("The rc of positive edges in G5 is ","%3.3f" %rp5)
print("The rc of positive edges in G5 is ","%3.3f" %rn5)
# Out:
# ('The rc of positive edges in G5 is ', '-0.061')
# ('The rc of positive edges in G5 is ', '-0.064')

# %%
knn_p5=nx.k_nearest_neighbors(Gp)
knn_n5=nx.k_nearest_neighbors(Gn)

# %%
def knn_to_list(knn_dict):
    list_keys=list(knn_dict)
    knn_list=[]
    for item in list_keys:
        knn_list.append((int(item),knn_dict[item]))
    knn_list_new=sorted(knn_list, key=lambda knn_list: knn_list[0])
    
    knn_degrees=[]
    knn_values=[]
    for item in knn_list_new:
        knn_degrees.append(item[0])
        knn_values.append(item[1])
    
    return knn_degrees,knn_values

# %%
knn_p0_degree,knn_p0_values=knn_to_list(knn_p0)
knn_n0_degree,knn_n0_values=knn_to_list(knn_n0)

knn_p1_degree,knn_p1_values=knn_to_list(knn_p1)
knn_n1_degree,knn_n1_values=knn_to_list(knn_n1)

knn_p2_degree,knn_p2_values=knn_to_list(knn_p2)
knn_n2_degree,knn_n2_values=knn_to_list(knn_n2)

knn_p3_degree,knn_p3_values=knn_to_list(knn_p3)
knn_n3_degree,knn_n3_values=knn_to_list(knn_n3)

knn_p4_degree,knn_p4_values=knn_to_list(knn_p4)
knn_n4_degree,knn_n4_values=knn_to_list(knn_n4)

knn_p5_degree,knn_p5_values=knn_to_list(knn_p5)
knn_n5_degree,knn_n5_values=knn_to_list(knn_n5)

# %%
figure(figsize=(15,10))
loglog(knn_p0_degree,knn_p0_values,'bo-',label='original')
loglog(knn_p1_degree,knn_p1_values,'rs',label='positive')
#loglog(knn_p2_degree,knn_p2_values,'y.-',label='negtive')
loglog(knn_p3_degree,knn_p3_values,'y-',label='positive and negtive')
loglog(knn_p4_degree,knn_p4_values,'g-',label='sign')
loglog(knn_p5_degree,knn_p5_values,'k-',label='full')
xlabel('$k$', fontsize=22)
ylabel('$k_{nn}<k>$', fontsize=22)
xlim([0, 100])
ylim([130, 300])
legend(loc='lower right',ncol = 1, fontsize=20)
savefig("knnp.pdf")

# %%
figure(figsize=(15,10))
loglog(knn_n0_degree,knn_n0_values,'bo-',label='original')
#loglog(knn_n1_degree,knn_n1_values,'r-',label='positive')
loglog(knn_n2_degree,knn_n2_values,'r-',label='negtive')
loglog(knn_n3_degree,knn_n3_values,'y-',label='positive and negtive')
loglog(knn_n4_degree,knn_n4_values,'g-',label='sign')
loglog(knn_n5_degree,knn_n5_values,'k-',label='full')
xlabel('$k$', fontsize=22)
ylabel('$k_{nn}<k>$', fontsize=22)
xlim([0, 1000])
ylim([30, 230])
legend(loc='lower left',ncol = 1, fontsize=20)
savefig("knnn.pdf")

# %%
def CommonNeighbor(G,nodeij):
    node_i=nodeij[0]
    node_j=nodeij[1]
    neigh_i=set(G.neighbors(node_i))
    neigh_j=set(G.neighbors(node_j))
    neigh_ij=neigh_i.intersection(neigh_j)
    num_cn=len(neigh_ij)       
    return num_cn

# %%
def CN_embedding(G,Gpn):
    CN_list=[]
    for item in G.edges():
        try:
            item_CN=CommonNeighbor(Gpn,item)
            CN_list.append((item_CN,G[item[0]][item[1]]['weight']))
        except:
            pass

    CN_list_sort=sorted(CN_list, key=lambda CN_list: CN_list[0])
    degree_list=[]
    positive_edge_cn=[]

    positve_edge_number=0
    sum_edge_number=0
    item_index=0
    for item in CN_list_sort:
        if item[0]==item_index:
            if item[1]==1:
                positve_edge_number=positve_edge_number+1
            sum_edge_number=sum_edge_number+1
        elif item[0]>item_index:
            if sum_edge_number==0:
                degree_list.append(item_index)
                positive_edge_cn.append(0)
            else:  
                degree_list.append(item_index)
                positive_edge_cn.append(float(positve_edge_number)/sum_edge_number)
            item_index=item[0]
            positve_edge_number=0
            sum_edge_number=0
    return degree_list,positive_edge_cn

# %%
Gp,Gn=divide_network(G)
degree_list_p0,positive_edge_cn_p0=CN_embedding(G,Gp)
degree_list_n0,positive_edge_cn_n0=CN_embedding(G,Gn)

# %%
Gp,Gn=divide_network(G1)
degree_list_p1,positive_edge_cn_p1=CN_embedding(G1,Gp)
degree_list_n1,positive_edge_cn_n1=CN_embedding(G1,Gn)

# %%
Gp,Gn=divide_network(G2)
degree_list_p2,positive_edge_cn_p2=CN_embedding(G2,Gp)
degree_list_n2,positive_edge_cn_n2=CN_embedding(G2,Gn)

# %%
Gp,Gn=divide_network(G3)
degree_list_p3,positive_edge_cn_p3=CN_embedding(G3,Gp)
degree_list_n3,positive_edge_cn_n3=CN_embedding(G3,Gn)

# %%
Gp,Gn=divide_network(G4)
degree_list_p4,positive_edge_cn_p4=CN_embedding(G4,Gp)
degree_list_n4,positive_edge_cn_n4=CN_embedding(G4,Gn)

# %%
Gp,Gn=divide_network(G5)
degree_list_p5,positive_edge_cn_p5=CN_embedding(G5,Gp)
degree_list_n5,positive_edge_cn_n5=CN_embedding(G5,Gn)

# %%
figure(figsize=(15,10))
semilogx(degree_list_p0,positive_edge_cn_p0,'ro-',label='original')
semilogx(degree_list_p1,positive_edge_cn_p1,'bs-',label='positive')
semilogx(degree_list_p2,positive_edge_cn_p2,'yd-',label='negtive')
semilogx(degree_list_p3,positive_edge_cn_p3,'g.-',label='positive and negtive')
semilogx(degree_list_p4,positive_edge_cn_p4,'k^-',label='sign')
semilogx(degree_list_p5,positive_edge_cn_p5,'m*-',label='full')
xlim([0, 80])
ylim([0.8, 0.99])
xlabel('Number of common numbers', fontsize=22)
ylabel('Fraction of plus edges', fontsize=22)
legend(loc='upper left',ncol = 1, fontsize=20)
savefig("embedding_positive_links1.pdf")

# %%
figure(figsize=(15,10))
plot(degree_list_n0,positive_edge_cn_n0,'ro-',label='original')
plot(degree_list_n1,positive_edge_cn_n1,'bs-',label='positive')
plot(degree_list_n2,positive_edge_cn_n2,'yd-',label='negtive')
plot(degree_list_n3,positive_edge_cn_n3,'g.-',label='positive and negtive')
plot(degree_list_n4,positive_edge_cn_n4,'k^-',label='sign')
plot(degree_list_n5,positive_edge_cn_n5,'m*-',label='full')
xlim([0.95, 10])
ylim([0.3, 0.85])

xlabel('Number of common numbers', fontsize=22)
ylabel('Fraction of plus edges', fontsize=22)
legend(loc='lower left',ncol = 1, fontsize=20)
savefig("embedding_positive_links2.pdf")
